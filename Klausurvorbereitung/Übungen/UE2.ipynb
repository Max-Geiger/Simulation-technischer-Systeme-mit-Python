# %%
#import
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Aufgabe 2.10
df = pd.read_excel('UE2_MeineDaten.xlsx')
print(df)
# Out:
#     Zeit   Sensor1   Sensor2
# 0    0.0  0.000000  1.000000
# 1    0.1  0.099833  0.995004
# 2    0.2  0.198669  0.980067
# 3    0.3  0.295520  0.955336
# 4    0.4  0.389418  0.921061
# ..   ...       ...       ...
# 58   5.8 -0.464602  0.885520
# 59   5.9 -0.373877  0.927478
# 60   6.0 -0.279415  0.960170
# 61   6.1 -0.182163  0.983268
# 62   6.2 -0.083089  0.996542
#
# [63 rows x 3 columns]

# %%
#Aufgabe 2.11
t = np.arange(0,2*np.pi,0.1)
def Funktion(t):
    return np.sin(t)

y=Funktion(t)
df = pd.Series(y,t)
df.to_excel("Funktion.xlsx",sheet_name='Sheet_name_1')
print(df)
plt.plot(t,Funktion(t))
plt.show()
# Out:
# 0.0    0.000000
# 0.1    0.099833
# 0.2    0.198669
# 0.3    0.295520
# 0.4    0.389418
#          ...
# 5.8   -0.464602
# 5.9   -0.373877
# 6.0   -0.279415
# 6.1   -0.182163
# 6.2   -0.083089
# Length: 63, dtype: float64

# %%
#Aufgabe 2.13


x=np.linspace(0,10,51)
def Polynom(x,a=1,b=1,c=0): 
    fx = a*x**2+b*x+c
    return fx 

fx = Polynom(x)

def PolyDiff(x,fx):
    y_diff=[]
    for n in range(1,len(fx)-1):
        y_diff.append((fx[n+1] - fx[n-1])/(2*(x[n+1]-x[n]))) 
    return y_diff

y2_diff = PolyDiff(x,fx)
# postprocessing
plt.plot(x,fx,label="y") #Hier werden die Werte zum Plottenübergeben
plt.plot(x,y2_diff,label="y'")
plt.legend()
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2b/5lvf8bqx2pq9vmy39gcbrlnh0000gn/T/ipykernel_14543/2180866291.py in <module>
#      18 # postprocessing
#      19 plt.plot(x,fx,label="y") #Hier werden die Werte zum Plottenübergeben
# ---> 20 plt.plot(x,y2_diff,label="y'")
#      21 plt.legend()
#      22 plt.grid()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (51,) and (49,)
